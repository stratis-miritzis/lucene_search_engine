# %%
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("C:/Users/User/Documents/database.sqlite")
artists = pd.read_sql_query("SELECT * from artists", con)
# content = pd.read_sql_query("SELECT * from content", con)
genres = pd.read_sql_query("SELECT * from genres", con)
labels = pd.read_sql_query("SELECT * from labels", con)
# reviews = pd.read_sql_query("SELECT * from reviews", con)
years = pd.read_sql_query("SELECT * from years", con)

# %%
final = content.merge(reviews, left_on='reviewid', right_on='reviewid')
final = final.merge(labels, left_on='reviewid', right_on='reviewid')

# %%
final
# Out:
#        reviewid                                            content  \
# 0         22703  “Trip-hop” eventually became a ’90s punchline,...
# 1         22721  Eight years, five albums, and two EPs in, the ...
# 2         22659  Minneapolis’ Uranium Club seem to revel in bei...
# 3         22659  Minneapolis’ Uranium Club seem to revel in bei...
# 4         22661  Kleenex began with a crash. It transpired one ...
# ...         ...                                                ...
# 20215      1535  The marketing guys of yer average modern megac...
# 20216      1341  Well, it's been two weeks now, and I guess it'...
# 20217      5376  Out of Tune is a Steve Martin album.  Yes, I'l...
# 20218      2413  Well, kids, I just went back and re-read my re...
# 20219      3723  Neil Hamburger's third comedy release is a des...
#
#                              title            artist  \
# 0                        mezzanine    massive attack
# 1                     prelapsarian          krallice
# 2             all of them naturals      uranium club
# 3             all of them naturals      uranium club
# 4                      first songs  kleenex, liliput
# ...                            ...               ...
# 20215               let us replay!           coldcut
# 20216                         1999           cassius
# 20217                  out of tune          mojave 3
# 20218  singles breaking up, vol. 1     don caballero
# 20219    left for dead in malaysia    neil hamburger
#
#                                                      url  score  \
# 0      http://pitchfork.com/reviews/albums/22703-mezz...    9.3
# 1      http://pitchfork.com/reviews/albums/22721-prel...    7.9
# 2      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 3      http://pitchfork.com/reviews/albums/22659-all-...    7.3
# 4      http://pitchfork.com/reviews/albums/22661-firs...    9.0
# ...                                                  ...    ...
# 20215  http://pitchfork.com/reviews/albums/1535-let-u...    8.9
# 20216     http://pitchfork.com/reviews/albums/1341-1999/    4.8
# 20217  http://pitchfork.com/reviews/albums/5376-out-o...    6.3
# 20218  http://pitchfork.com/reviews/albums/2413-singl...    7.2
# 20219  http://pitchfork.com/reviews/albums/3723-left-...    6.5
#
#        best_new_music           author               author_type    pub_date  \
# 0                   0      nate patrin               contributor  2017-01-08
# 1                   0         zoe camp               contributor  2017-01-07
# 2                   0   david glickman               contributor  2017-01-07
# 3                   0   david glickman               contributor  2017-01-07
# 4                   1       jenn pelly  associate reviews editor  2017-01-06
# ...               ...              ...                       ...         ...
# 20215               0  james p. wisdom                      None  1999-01-26
# 20216               0  james p. wisdom                      None  1999-01-26
# 20217               0   jason josephes               contributor  1999-01-12
# 20218               0  james p. wisdom                      None  1999-01-12
# 20219               0   jason josephes               contributor  1999-01-05
#
#        pub_weekday  pub_day  pub_month  pub_year               label
# 0                6        8          1      2017              virgin
# 1                5        7          1      2017           hathenter
# 2                5        7          1      2017        static shock
# 3                5        7          1      2017  fashionable idiots
# 4                4        6          1      2017     kill rock stars
# ...            ...      ...        ...       ...                 ...
# 20215            1       26          1      1999          ninja tune
# 20216            1       26          1      1999         astralwerks
# 20217            1       12          1      1999                 4ad
# 20218            1       12          1      1999        touch and go
# 20219            1        5          1      1999           drag city
#
# [20220 rows x 15 columns]
